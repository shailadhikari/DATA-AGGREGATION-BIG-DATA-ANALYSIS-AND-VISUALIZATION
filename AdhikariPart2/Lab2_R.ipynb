# %%
#-----------------------------------------Lab 2 R-------------------------------------------------
#First we install package rTweets and then use it as a library

# %%
library(rtweet)
## whatever name you assigned to your created app
appname <- "Lab1"

## api key (example below is not a real key)
key <- "h4yIchStXOT438JZNHUglBmsK"

## api secret (example below is not a real key)
secret <- "z7CKhKV7tSjTl6X0QLdTcIQzxkb08L1XvC8N6oLy6sM2O54DR6"

## create token named "twitter_token"
twitter_token <- create_token(
  app = appname,
  consumer_key = key,
  consumer_secret = secret)

## path of home directory
home_directory <- path.expand("~/")

## combine with name for token
file_name <- file.path(home_directory, "twitter_token.rds")

## save token to home directory
saveRDS(twitter_token, file = file_name)

## On my mac, the .Renviron text looks like this:
##     TWITTER_PAT=/Users/mwk/twitter_token.rds

## assuming you followed the procodures to create "file_name"
##     from the previous code chunk, then the code below should
##     create and save your environment variable.
cat(paste0("TWITTER_PAT=", file_name),
    file = file.path(home_directory, ".Renviron"),
    append = TRUE)
# Out:
# Waiting for authentication in browser...
# Press Esc/Ctrl + C to abort
# Please point your browser to the following url:
# https://api.twitter.com/oauth/authenticate?oauth_token=na6PSwAAAAAA4li3AAABYp6LHGY&permission=read
# Authentication complete.

# %%
library(rtweet)
data_trump <- search_tweets("#trump", n = 3000, include_rts = FALSE)
head(data_trump)
nrow(data_trump)
write.table(data_trump$text,"FileTwitterTrump_Raw.txt",sep="\t",row.names=FALSE)
# Out:
# Searching for tweets...
# Finished collecting tweets!
#   status_id          created_at          user_id            screen_name
# 1 982528345333293056 2018-04-07 07:59:46 794255890736152582 Normalbloke69
# 2 982528286130561025 2018-04-07 07:59:32 15724860           LNSmithee
# 3 982528187363201024 2018-04-07 07:59:09 747451360715616257 giu33liana
# 4 982528172209008640 2018-04-07 07:59:05 30132130           JimScotty
# 5 982528130576453632 2018-04-07 07:58:55 531653941          hlotro
# 6 982528068899278848 2018-04-07 07:58:40 522537060          PoliticsNewz
#   text
# 1 #HRCVideo #HilaryClintonVideo\n#DropTheHammer #ThesePeopleAreSick\n#GreatAwakening #WeThePeople #Q #QAnon #Qanon8chan #8chan #QClearance #Bread #Breadcrumbs\n#Crumbs #CrookedHillary #FollowTheWhiteRabbit #RedPill #Trump #MAGA #POTUS #Pizzagate\nWhaaaat? https://t.co/yZZ6loBfDJ
# ...

# %%
library(rtweet)
data_immigration <- search_tweets("#immigration", n = 3000, include_rts = FALSE)
head(data_immigration)
nrow(data_immigration)
write.table(data_immigration$text,"FileTwitterImmigration_Raw.txt",sep="\t",row.names=FALSE)
# Out:
# Searching for tweets...
# Finished collecting tweets!
#   status_id          created_at          user_id            screen_name
# 1 982528548471795712 2018-04-07 08:00:35 468230569          AstonBrooke
# 2 982528480628936705 2018-04-07 08:00:18 4729219604         gidssusa
# 3 982528439491100673 2018-04-07 08:00:09 890541566212935680 BrexitUKReality
# 4 982528017279930369 2018-04-07 07:58:28 306958844          Max_in_Vienna
# 5 982527088778412032 2018-04-07 07:54:47 1677531192         AlahednewsEn
# 6 982526606739636224 2018-04-07 07:52:52 325308989          Mel_Functi0n
#   text
# 1 Want to know more about us? Why not check out our awesome website for more information on the services we provide. https://t.co/ZkQXU68gjI #immigration #llitigation #personlinjury #conveyancing
# 2 Australia's immigration policy is meant to be blind to race, but is it? #gidss #gidssusa #australia #immigration #policy #race #blindrace Read more: https://t.co/xKWCsVzQFp https://t.co/wuXtCQ4oOh
# ...

# %%
library(rtweet)
data_h1b <- search_tweets("#h1b", n = 3000, include_rts = FALSE)
head(data_h1b)
nrow(data_h1b)
write.table(data_h1b$text,"FileTwitterH1B_Raw.txt",sep="\t",row.names=FALSE)
# Out:
# Searching for tweets...
# Finished collecting tweets!
#   status_id          created_at          user_id            screen_name
# 1 982495595012255746 2018-04-07 05:49:38 4060689334         ferarimone
# 2 982488374396309504 2018-04-07 05:20:56 797234508307320833 NavedTX
# 3 982475412902219776 2018-04-07 04:29:26 561313849          testtweeter010
# 4 982473390849130496 2018-04-07 04:21:24 561313849          testtweeter010
# 5 982471816177479680 2018-04-07 04:15:09 860301272376803332 dosakalyan
# 6 982471669825581056 2018-04-07 04:14:34 860301272376803332 dosakalyan
#   text
# 1 Another side of #h1b v much widespread in India. Fake marriage n use bride side dowry money to pay for US college fees n after getting GC abandon wife in India \U0001f1ee\U0001f1f3 https://t.co/GYy6idiBm4
# 2 Kill #H1B EB1C OPT CPT H4 CPT ALL #NOH1B \nTO PROTECT CTZNS FROM ALL KINDS OF INVASION IS GOVT JOB, including jobs, security etc @POTUS @VP https://t.co/nDVHnNJyWw
# ...
